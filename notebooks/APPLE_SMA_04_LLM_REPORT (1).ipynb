# %%
pip install --upgrade llama-index openai
# Out:
# Requirement already satisfied: llama-index in ./anaconda3/lib/python3.11/site-packages (0.12.22)
# Requirement already satisfied: openai in ./anaconda3/lib/python3.11/site-packages (1.65.3)
# Collecting openai
#   Downloading openai-1.65.4-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index) (0.4.6)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.1 in ./anaconda3/lib/python3.11/site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.22 in ./anaconda3/lib/python3.11/site-packages (from llama-index) (0.12.22)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index) (0.6.8)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index) (0.3.20)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index) (0.4.3)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index) (0.4.5)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in ./anaconda3/lib/python3.11/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./anaconda3/lib/python3.11/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./anaconda3/lib/python3.11/site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./anaconda3/lib/python3.11/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./anaconda3/lib/python3.11/site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./anaconda3/lib/python3.11/site-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in ./anaconda3/lib/python3.11/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in ./anaconda3/lib/python3.11/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in ./anaconda3/lib/python3.11/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in ./anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in ./anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in ./anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: PyYAML>=6.0.1 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./anaconda3/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.22->llama-index) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (3.9.3)
# Requirement already satisfied: dataclasses-json in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (2023.10.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (3.1)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (8.2.2)
# Requirement already satisfied: tiktoken>=0.3.3 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (0.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in ./anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.22->llama-index) (1.14.1)
# Requirement already satisfied: llama-cloud<0.2.0,>=0.1.13 in ./anaconda3/lib/python3.11/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.13)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in ./anaconda3/lib/python3.11/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (4.13.3)
# Requirement already satisfied: pandas in ./anaconda3/lib/python3.11/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.1.4)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (5.3.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in ./anaconda3/lib/python3.11/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in ./anaconda3/lib/python3.11/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.1)
# Requirement already satisfied: click in ./anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in ./anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in ./anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index) (2023.10.3)
# Requirement already satisfied: annotated-types>=0.6.0 in ./anaconda3/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./anaconda3/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.22->llama-index) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in ./anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.22->llama-index) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.22->llama-index) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.22->llama-index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.22->llama-index) (1.9.3)
# Requirement already satisfied: soupsieve>1.2 in ./anaconda3/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.5)
# Requirement already satisfied: llama-cloud-services>=0.6.1 in ./anaconda3/lib/python3.11/site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.22->llama-index) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.22->llama-index) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in ./anaconda3/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.22->llama-index) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./anaconda3/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.22->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./anaconda3/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.22->llama-index) (3.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./anaconda3/lib/python3.11/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.11/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./anaconda3/lib/python3.11/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2023.3)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in ./anaconda3/lib/python3.11/site-packages (from llama-cloud-services>=0.6.1->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.0.1)
# Requirement already satisfied: packaging>=17.0 in ./anaconda3/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.22->llama-index) (23.1)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (1.16.0)
# Downloading openai-1.65.4-py3-none-any.whl (473 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.5/473.5 kB 903.4 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.65.3
#     Uninstalling openai-1.65.3:
#       Successfully uninstalled openai-1.65.3
# Successfully installed openai-1.65.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pickle
import openai
import numpy as np
import pandas as pd
import tensorflow as tf
from rich.console import Console
from rich.markdown import Markdown
from llama_index.core import Settings
from llama_index.llms.openai import OpenAI
# Out:
# ✅ LSTM Model Loaded: /Users/adityaiyer/Desktop/APPLE_SMA/models/lstm_model.keras
# ✅ Scaler Loaded: /Users/adityaiyer/Desktop/APPLE_SMA/models/scaler.pkl
# ✅ Predictions Loaded: /Users/adityaiyer/Desktop/APPLE_SMA/models/predictions.csv
# /Users/adityaiyer/anaconda3/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 18 variables whereas the saved optimizer has 35 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Define paths
models_path = "/Users/adityaiyer/Desktop/APPLE_SMA/models"
model_path = os.path.join(models_path, "lstm_model.keras")
scaler_path = os.path.join(models_path, "scaler.pkl")
predictions_path = os.path.join(models_path, "predictions.csv")

# Load the trained LSTM model
model = tf.keras.models.load_model(model_path)
print(f"✅ LSTM Model Loaded: {model_path}")

# Load the scaler
with open(scaler_path, 'rb') as f:
    scaler = pickle.load(f)
print(f"✅ Scaler Loaded: {scaler_path}")

# Load the predictions
predictions_df = pd.read_csv(predictions_path)
print(f"✅ Predictions Loaded: {predictions_path}")

# Extract forecasted and historical prices
forecasted_prices = predictions_df["Predicted Price"].values.flatten().tolist()
historical_prices = predictions_df["Actual Price"].values[-100:].flatten().tolist()  # Last 100 days

# %%
# Setup OpenAI API key
openai.api_key = "YOUR API KEY HERE"

# %%
# Configure LlamaIndex Settings
Settings.llm = OpenAI(model="gpt-4", temperature=0.7)

# %%
# Improved Structured Prompt
summary_prompt = f"""
You are a financial analyst providing insights on stock market trends.
Analyze the **historical stock prices (last 100 days)** and **predicted values (next 30 days)** from an LSTM model.

**Key Areas to Cover:**
1️⃣ **Trend Analysis:** Identify overall trends (upward/downward, volatility, stability).
2️⃣ **Comparison:** Highlight differences between actual and predicted prices.
3️⃣ **Risk Factors:** Discuss key risks such as market conditions, volatility, and external factors.
4️⃣ **Investment Insights:** Offer potential strategies based on predictions.

📊 **Historical Prices (last 100 days):**
{historical_prices}

📈 **Forecasted Prices (next 30 days):**
{forecasted_prices}

Provide the insights in a structured, professional financial tone.
"""

# %%
# Query the LLM for insights
llm = OpenAI(model="gpt-4")
llm_response = llm.complete(summary_prompt)

# %%
# Display AI insights with better formatting
console = Console()
output = f"""
# 📊 AI-Generated Stock Forecast Insights

## 📈 Trend Analysis:
{llm_response}

---

🔹 **Key Takeaways:**
✅ Market **momentum** suggests a trend of __upward movement__.  
✅ **Predicted fluctuations** indicate potential short-term volatility.  
✅ **Investment Caution**: Watch for **market signals & risk factors**.

💡 **Final Advice**: Diversify investments and follow **real-time market news** for better decision-making.
"""

console.print(Markdown(output))
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                     📊 AI-Generated Stock Forecast Insights                                     ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
#
#                                                 📈 Trend Analysis:
#
# 1️⃣ Trend Analysis:
#
# The historical stock prices over the last 100 days show a general upward trend, with the stock price increasing
# from around 225 to 235. However, there have been periods of volatility, with the stock price fluctuating between
# highs of approximately 247 and lows of around 222. The stock has shown a degree of stability in recent times, with
# less pronounced fluctuations.
#
# 2️⃣ Comparison:
#
# Comparing the historical prices with the forecasted prices from the LSTM model, there is a noticeable difference.
# The model predicts a slight downward trend in the stock price over the next 30 days, with the price decreasing from
# around 221 to 241. This is in contrast to the upward trend observed in the historical data. The model also predicts
# less volatility in the stock price compared to the historical data.
#
# 3️⃣ Risk Factors:
#
# The key risks associated with this stock include market conditions, volatility, and external factors. Market
# conditions can significantly impact the stock price, with economic downturns potentially leading to decreases in
# the stock price. The stock has shown volatility in the past, which could lead to potential losses if the stock
# price decreases. External factors such as changes in industry trends, regulatory changes, and geopolitical events
# can also impact the stock price.
#
# 4️⃣ Investment Insights:
#
# Based on the LSTM model's predictions, potential strategies could include shorting the stock if the predicted
# downward trend materializes. However, given the historical upward trend and recent stability, a long-term
# investment strategy could also be considered. Investors should monitor market conditions and external factors
# closely and adjust their strategies accordingly. It's also important to consider the model's predictions as one of
# many tools in an investor's toolkit, and not a definitive guide to future stock performance. Diversification of the
# investment portfolio to spread risk would also be a prudent strategy.
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# 🔹 Key Takeaways: ✅ Market momentum suggests a trend of upward movement.
# ✅ Predicted fluctuations indicate potential short-term volatility.
# ✅ Investment Caution: Watch for market signals & risk factors.
#
# 💡 Final Advice: Diversify investments and follow real-time market news for better decision-making.

# %%
import os

# Define reports directory
reports_path = "/Users/adityaiyer/Desktop/APPLE_SMA/reports"

# Ensure the reports directory exists
if not os.path.exists(reports_path):
    os.makedirs(reports_path)
    print(f"✅ Created directory: {reports_path}")
else:
    print(f"📂 Directory already exists: {reports_path}")

# Define file paths
md_report_path = os.path.join(reports_path, "ai_report.md")
txt_report_path = os.path.join(reports_path, "ai_report.txt")

# Extract the actual text from LLM response
llm_text = llm_response.text  # ✅ FIX: Convert to string

# Save report in Markdown format
with open(md_report_path, "w", encoding="utf-8") as f:
    f.write(output)
print(f"✅ AI Report saved as Markdown: {md_report_path}")

# Save report in Text format
with open(txt_report_path, "w", encoding="utf-8") as f:
    f.write(llm_text)  # ✅ FIX: Write as string
print(f"✅ AI Report saved as Text: {txt_report_path}")
# Out:
# 📂 Directory already exists: /Users/adityaiyer/Desktop/APPLE_SMA/reports
# ✅ AI Report saved as Markdown: /Users/adityaiyer/Desktop/APPLE_SMA/reports/ai_report.md
# ✅ AI Report saved as Text: /Users/adityaiyer/Desktop/APPLE_SMA/reports/ai_report.txt
